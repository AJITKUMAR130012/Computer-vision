# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import easyocr
import math

# %%
img=cv2.imread("./Dataset/india-map.jpg")

# %%
plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (834, 700, 3)

# %%
reader = easyocr.Reader(['en'])
result = reader.readtext(img)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
print(result)
# Out:
# [([[51, 5], [107, 5], [107, 19], [51, 19]], 'Tniikistal', 0.16009526434695096), ([[516, 14], [632, 14], [632, 44], [516, 44]], 'N D | A', 0.9153072764592999), ([[440, 42], [686, 42], [686, 66], [440, 66]], 'States and Union Territories', 0.9166186114146313), ([[209, 63], [259, 63], [259, 77], [209, 77]], 'LADAKH', 0.9991422102894095), ([[151, 71], [201, 71], [201, 85], [151, 85]], 'Srinagar', 0.9957992992333693), ([[147, 89], [189, 89], [189, 103], [147, 103]], 'JAMMU', 0.9994788590226454), ([[233, 89], [257, 89], [257, 103], [233, 103]], 'Leh', 0.999945903340925), ([[541, 87], [617, 87], [617, 103], [541, 103]], 'INDIA FLAG', 0.9959065461269254), ([[145, 101], [199, 101], [199, 115], [145, 115]], 'KASHMIR', 0.7258352754926256), ([[173, 117], [213, 117], [213, 129], [173, 129]], 'Jammnu', 0.7854362002458498), ([[195, 129], [255, 129], [255, 143], [195, 143]], 'HIMACHAL', 0.7015882347682061), ([[199, 143], [253, 143], [253, 159], [199, 159]], 'PRADESH', 0.999287794169603), ([[161, 159
# ...

# %%
n=len(result)
n
# Out:
# 108

# %%
len(result[0])
# Out:
# 3

# %%
len(result[0][0])
# Out:
# 4

# %%
ans1=0
ans2=0
x1=0
y1=0
x2=0
y2=0

for i in range(n):
    if result[i][1]=="BIHAR":
        x1=(result[i][0][0][0] + result[i][0][1][0])/2
        y1=(result[i][0][0][1] + result[i][0][2][1])/2
        
    if result[i][1]=="RAJASTHAN":
        x2=(result[i][0][0][0] + result[i][0][1][0])/2
        y2=(result[i][0][0][1] + result[i][0][2][1])/2
print(x1,y1)
print(x2,y2)
# Out:
# 440.0 303.0
# 135.0 290.0

# %%
p=[x1,y1]
q=[x2,y2]
print (math.dist(p, q))
# Out:
# 305.2769234645816
