# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread("./Dataset/5/025a0eea25d9986b.jpg")

# %%
plt.imshow(img)

# %%
plt.hist(img.flat, bins=10, edgecolor="yellow", color="green")
# Out:
# (array([1.45000e+02, 7.06410e+04, 2.24277e+05, 2.40187e+05, 2.14023e+05,
#         2.68329e+05, 2.48971e+05, 4.17700e+04, 2.79200e+03, 2.40000e+01]),
#  array([ 20.,  42.,  64.,  86., 108., 130., 152., 174., 196., 218., 240.]),
#  <BarContainer object of 10 artists>)

# %%
img.shape, len((img.flat))
# Out:
# ((799, 547, 3), 1311159)
